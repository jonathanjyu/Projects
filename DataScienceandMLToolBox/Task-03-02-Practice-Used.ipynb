# %% [markdown]
# # Task #03 指定教材 02：靜態網頁爬蟲實作
# Practice

# %%
import requests

url = 'https://api.github.com/user'
r = requests.get(url, auth=('user', 'pass'))
print(r.status_code)

print(r.text)

print(r.json())
# Out:
# 401
# {"message":"Requires authentication","documentation_url":"https://docs.github.com/rest/users/users#get-the-authenticated-user"}
# {'message': 'Requires authentication', 'documentation_url': 'https://docs.github.com/rest/users/users#get-the-authenticated-user'}

# %%
r1 = requests.get('https://api.github.com/events')
r1.text
# Out:
# '[{"id":"37948470726","type":"PushEvent","actor":{"id":166611144,"login":"minder-smoke-tests-infra[bot]","display_login":"minder-smoke-tests-infra","gravatar_id":"","url":"https://api.github.com/users/minder-smoke-tests-infra[bot]","avatar_url":"https://avatars.githubusercontent.com/u/166611144?"},"repo":{"id":794002760,"name":"minder-smoke-tests/smoke-test-python-5785","url":"https://api.github.com/repos/minder-smoke-tests/smoke-test-python-5785"},"payload":{"repository_id":794002760,"push_id":18216906472,"size":1,"distinct_size":0,"ref":"refs/heads/testmain","head":"a5ff18cc8c7cc506ad691584c05244929aa22e02","before":"0000000000000000000000000000000000000000","commits":[{"sha":"a5ff18cc8c7cc506ad691584c05244929aa22e02","author":{"email":"166611144+minder-smoke-tests-infra[bot]@users.noreply.github.com","name":"minder-smoke-tests-infra[bot]"},"message":"Initialize testmain","distinct":false,"url":"https://api.github.com/repos/minder-smoke-tests/smoke-test-python-5785/commits/a5ff18cc8c7cc506ad691584c05244929aa22e02"}]},"public":true,"created_at":"2024-04-30T09:17:37Z","org":{"id":166534298,"login":"minder-smoke-tests","gravatar_id":"","url":"https://api.github.com/orgs/minder-smoke-tests","avatar_url":"https://avatars.githubusercontent.com/u/166534298?"}},{"id":"37948470782","type":"PushEvent","actor":{"id":143246539,"login":"Tharuka-Wijethunga","display_login":"Tharuka-Wijethunga","gravatar_id":"","url":"https://api.github.com/users/Tharuka-Wijethunga","avatar_url":"https://avatars.githubusercontent.com/u/143246539?"},"repo":{"id":782081414,"name":"Tharuka-Wijethunga/InSync-Backend","url":"https://api.github.com/repos/Tharuka-Wijethunga/InSync-Backend"},"payload":{"repository_id":782081414,"push_id":18216906578,"size":8,"distinct_size":0,"ref":"refs/heads/Tharuka","head":"290de9ed4a8cb6f0fa011ce43361617a2fce4b8d","before":"50dc4497c5987a8a616702dd1a082b33c0703476","commits":[{"sha":"dff265e9699cd2c41e81a94047c4d70241d52575","author":{"email":"lihajwickramasinghe@gmail.com","name":"Lihaj"},"message":"lihaj added a comment","distinct":false,"url":"https://api.github.com/repos/Tharuka-Wijethunga/InSync-Backend/commits/dff265e9699cd2c41e81a94047c4d70241d52575"},{"sha":"eec867a42084fd23f5a49ad369ee627cc0864dff","author":{"email":"143246539+Tharuka-Wijethunga@users.noreply.github.com","name":"Tharuka Wijethunga"},"message":"Merge pull request #3 from Tharuka-Wijethunga/Lihaj\\n\\nLihaj added comment","distinct":false,"url":"https://api.github.com/repos/Tharuka-Wijethunga/InSync-Backend/commits/eec867a42084fd23f5a49ad369ee627cc0864dff"},{"sha":"c0caaf46ba2a335fb57b92d70d924c7ed696bc0c","author":{"email":"143246539+Tharuka-Wijethunga@users.noreply.github.com","name":"Tharuka Wijethunga"},"message":"Merge pull request #4\\n\\n2nd comment check for lihaj branch","distinct":false,"url":"https://api.github.com/repos/Tharuka-Wijethunga/InSync-Backend/commits/c0caaf46ba2a335fb57b92d70d924c7ed696bc0c"},{"sha":"e7fda72568b8b1dceddcba36d1a964f37da7aaca","author":{"email":"143246539+Tharuka-Wijethunga@users.noreply.github.com","name":"Tharuka Wijethunga"},"message":"Merge pull request #5\\n\\nAdd Record POST method done .(without date & time)","distinct":false,"url":"https://api.github.com/repos/Tharuka-Wijethunga/InSync-Backend/commits/e7fda72568b8b1dceddcba36d1a964f37da7aaca"},{"sha":"b1c8b8944613330a0cc815d170b63549395ba6f2","author":{"email":"143246539+Tharuka-Wijethunga@users.noreply.github.com","name":"Tharuka Wijethunga"},"message":"Merge pull request #6\\n\\nAddRecord post method completed.","distinct":false,"url":"https://api.github.com/repos/Tharuka-Wijethunga/InSync-Backend/commits/b1c8b8944613330a0cc815d170b63549395ba6f2"},{"sha":"c93fe33766e3e632db67bf746b9b46a5177c343d","author":{"email":"143246539+Tharuka-Wijethunga@users.noreply.github.com","name":"Tharuka Wijethunga"},"message":"Merge pull request #7\\n\\nGet record by Id and Get all the records in the database requests done.","distinct":false,"url":"https://api.github.com/rep ...

# %%
r = requests.put('https://httpbin.org/put', data={'key': 'value'})
r = requests.delete('https://httpbin.org/delete')
r = requests.head('https://httpbin.org/get')
r = requests.options('https://httpbin.org/get')

# %%
r
# Out:
# <Response [200]>
